# %%
import os 
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
os.getcwd()
# Out:
# 'd:\\Desktop\\goruntu_isleme-derin_ogrenme'

# %%
os.chdir('d:\\Desktop\\goruntu_isleme-derin_ogrenme\\opencv_nesne_tespiti\\kenar_algılama\\input')

# %%
img = cv2.imread("london.jpg")

# %%
edge = cv2.Canny(img ,0,255)

# %%
plt.imshow(edge)
