# %%
import os 
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
os.getcwd()
# Out:
# 'd:\\Desktop\\goruntu_isleme-derin_ogrenme\\opencv_ile_görüntü_isleme\\görüntü_eşikleme\\src'

# %%
os.chdir("d:\\Desktop\\goruntu_isleme-derin_ogrenme\\opencv_ile_görüntü_isleme\\görüntü_eşikleme\\input")

# %%
os.getcwd()
# Out:
# 'd:\\Desktop\\goruntu_isleme-derin_ogrenme\\opencv_ile_görüntü_isleme\\görüntü_eşikleme\\input'

# %%
img = cv2.imread("manzara2.jpg",0)

# %%
plt.imshow(img)

# %%
plt.imshow(img ,cmap = "gray")

# %%
img.shape
# Out:
# (165, 305)

# %%
hist = cv2.calcHist([img],[0],None , [256],[0,256])

# %%
hist
# Out:
# array([[172.],
#        [ 57.],
#        [ 71.],
#        [ 75.],
#        [ 96.],
#        [ 82.],
#        [ 70.],
#        [101.],
#        [ 95.],
#        [ 88.],
#        [102.],
#        [ 68.],
#        [ 77.],
#        [ 70.],
#        [ 98.],
#        [ 81.],
#        [121.],
#        [122.],
#        [141.],
#        [135.],
#        [136.],
#        [121.],
#        [122.],
#        [141.],
#        [152.],
#        [163.],
#        [168.],
#        [188.],
#        [154.],
#        [181.],
#        [188.],
#        [166.],
#        [136.],
#        [125.],
#        [177.],
#        [142.],
#        [206.],
#        [174.],
#        [189.],
#        [230.],
#        [182.],
#        [179.],
#        [210.],
#        [178.],
#        [235.],
#        [163.],
#        [149.],
#        [184.],
#        [145.],
#        [178.],
#        [170.],
#        [214.],
#        [162.],
#        [204.],
#        [148.],
#        [189.],
#        [184.],
#        [188.],
# ...

# %%
plt.figure()
plt.plot(hist)
plt.xlabel("bins")
plt.ylabel("pixels")
plt.show()

# %%
_ , thresh = cv2.threshold(img , 100 ,255 ,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh)

# %%
_ , thresh = cv2.threshold(img , 100 ,255 ,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh , cmap = "gray")

# %%
_ , thresh = cv2.threshold(img , 100 ,255 ,cv2.THRESH_TOZERO)

# %%
plt.imshow(thresh  ,cmap = "gray")

# %%
_ , thresh = cv2.threshold(img , 100 ,255 ,cv2.THRESH_TOZERO_INV)

# %%
plt.imshow(thresh,cmap = "gray")

# %%
_ , thresh = cv2.threshold(img , 100 ,255 ,cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh ,cmap = "gray" )

# %%
thresh  = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,4)

# %%
plt.imshow(thresh , cmap = "gray")

# %%
thresh = cv2.adaptiveThreshold(img ,255 ,cv2.ADAPTIVE_THRESH_MEAN_C  ,cv2.THRESH_BINARY , 11,8 )

# %%
plt.imshow(thresh)
