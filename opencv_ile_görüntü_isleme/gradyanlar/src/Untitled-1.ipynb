# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt
import os

# %%
os.chdir("d:\\Desktop\\goruntu_isleme-derin_ogrenme\\opencv_ile_görüntü_isleme\\gradyanlar\\input")

# %%
img = cv2.imread("sudoku.png",0)

# %%
plt.imshow(img)

# %%
sobelx = cv2.Sobel(img ,ddepth= cv2.CV_16U ,dx = 1 , dy = 0 ,ksize = 5)

# %%
plt.imshow(sobelx)

# %%
sobely = cv2.Sobel(img , ddepth = cv2.CV_16U , dx = 0 , dy = 1 ,ksize = 5 )

# %%
plt.imshow(sobely)

# %%
laplacian = cv2.Laplacian(img , ddepth = cv2.CV_16U )

# %%
plt.imshow(laplacian)
